# %% [markdown]
# # Tema 8: Fuerzas gravitatorias
#
# #### ¿Qué es este documento?
#
# La página web que estás viendo es un *tema interactivo*. En él, aprenderás los conceptos que necesitas saber para resolver los problemas y superar con éxito la asignatura. Cada vez que haya un concepto nuevo o interesante, podrás acceder directamente a la [Wikipedia](https://es.wikipedia.org/wiki/Wikipedia), y en algunos ejercicios y ejemplos encontrarás **pequeños programas de ordenador interactivos** que tendrás que manipular para resolver los problemas, generar gráficas y jugar con la Física. **No te preocupes si lo _rompes_ y deja de funcionar**: Tan sólo tienes cerrar la página, volverla a abrir y *aquí no ha pasado nada*.
#
# #### ¿Cómo pruebo un programa?
#
# Para probar un programa, mantén pulsada la tecla _SHIFT_ y, sin soltarla, pulsa _ENTER_.
#
# #### ¿Qué vamos a aprender?
#
# Mediante esta página web vas a aprender cómo funciona la interacción gravitatoria entre dos cuerpos. Combinarás el *Movimiento Circular Uniforme* y las *Fuerzas Gravitatorias* al cálculo de órbitas de planetas.
#
# ## 1. Introducción
#
# La interacción gravitatoria entre dos cuerpos está descritas por la [**ley de Gravitación Universal**](http://es.wikipedia.org/wiki/ley_de_gravitacion_universal), enunciada por [Sir Isaac Newton](http://es.wikipedia.org/wiki/Isaac_Newton). Dicha ley dice así:
#
#
# <center>*Dos cuerpos cualesquiera, por el hecho de tener masa, se atraen mutuamente con una fuerza proporcional al producto de sus masas e inversamente proporcional al cuadrado de la distancia que los separa.*</center>
#
#
# Su expresión matemática es:
#
# $$F_{1,2} = G\,\frac{m_1 m_2}{r^2}$$
#
# ![Esquema](550px-NewtonsLawOfUniversalGravitation.png)
# <center>Fuente: *Dennis Nilsson, Crative Commons BY 3.0*</center>
#
# En esta fórmula sabemos qué significa $m_1$ (la masa del cuerpo 1 en kilogramos), $m_2$ (la masa del cuerpo 2, también en kilogramos), y $r$ (la distancia entre los dos cuerpos en metros). Pero... **¿Qué significa $G$?** **¿Qué es?**
#
# $G$ es la llamada [constante de gravitación universal](https://es.wikipedia.org/wiki/constante_de_gravitacion_universal), y su valor en el SI es de $G=6,67\cdot 10^{-11} N \cdot \frac{m^2}{kg^2}$. ¿Por qué tiene este valor tan raro? **Es un misterio**: en el Universo hay ciertas constantes que valen lo que valen sin que podamos encontrar ninguna razón y cuyo valor sólo puede ser obtenido mediante experimentos. Reciben el nombre de [constantes físicas universales](https://es.wikipedia.org/wiki/Constante_f%C3%ADsica).

# %% [markdown]
# #### Ejercicio 1
#
# Vamos a experimentar con esta nueva ley y vamos a calcular la fuerza con la que se atraen dos naranjas. Para ello, lo único que necesitamos conocer es su **masa** y la **distancia que los separa**.
#
# Supongamos que cada naranja tiene una masa de $100\,g$ (así, a ojo). Y las separamos $1\,m$ (una en cada mano).
#
# ¡Ya tenemos todos los datos! Ahora sencillamente aplicamos la fórmula que acabamos de aprender:
#
# $$F = G\,\frac{m_1 m_2}{r^2} = 6,67\cdot 10^{-11}\cdot \frac{0,1 \cdot 0,1}{1} = 6.67\cdot 10^{-13} = 0.000000000000667\, Newtons$$
#
# Eso es **poquísimo**.

# %% [markdown]
# ### 1.1 La gravitación es una fuerza, y es una magnitud vectorial
#
# ¿Recordamos cuáles eran las condiciones para que una magnitud sea vectorial?
#
# * Tiene un módulo
# * Tiene dirección
# * Tiene un sentido
#
# Cuando un objeto es atraído por la Tierra, y queremos representar su peso (es decir, la fuerza con la que es atraído) dibujamos un vector que va desde el objeto hacia abajo, con **módulo** $F=G\cdot\frac{m1\,m2}{d^2}$, **sentido** hacia abajo y **dirección** vertical.

# %% [markdown]
# ## 2. La aceleración de la gravedad
#
# En temas anteriores, habíamos visto que la aceleración de la gravedad es $g=9,81\,m/s$. Esto es algo que nos hemos *aprendido*, que *había que saber*. Vamos a ver ahora de dónde sale esto: Vamos a **deducir el valor de la aceleración de la gravedad**.
#
# Imaginemos la siguiente situación: Fulanito, que *tiene una masa de* $m_{Fulanito}=50\,kg$, está de pie en el patio del recreo. La única fuerza actuando sobre él es la gravedad:
#
# $$P_{Fulanito} = m_{Fulanito}\cdot g$$
#
# Si quisiésemos calcular el peso de Fulanito, multiplicaríamos su masa en kilos por $g=9,81\,m/s$ y listo. Pero vamos a suponer que **no** sabemos cuánto vale $g$. Nos hemos olvidado.
#
# Por suerte, recordamos la ley de la gravitación:
#
# $$P_{Fulanito}=G\, \frac{M_{Tierra}\cdot m_{Fulanito}}{R_{Tierra}^2}= g\cdot m_{Fulanito}$$
#
# Si nos fijamos bien en la ecuación, veremos que:
#
# $$g=G\,\frac{M_{Tierra}}{R_{Tierra}^2}$$.
#
# **¡Y lo mejor de todo es que la masa de Fulanito no interviene para nada!** Todo depende, únicamente, del planeta en el que estemos.
#
# Mirando en [Wikipedia](https://es.wikipedia.org/wiki/Tierra) la masa de la Tierra ($M_{Tierra}$) y su radio ($R_{Tierra}$), podemos ver que:
#
# $$g=6,67\, \left[ N \frac{m^2}{kg} \right] \cdot 10^{-11} \frac{5,9736\cdot 10^{24}\, [kg]}{6371000^2 \, [m^2]}=\textbf{9,81}6276 \, \left[ \frac{m}{s^2} \right]$$
#
# #### Ejercicio 2
#
# * ¿Eres capaz de calcular la aceleración de la gravedad en otros planetas? Halla $g_{Luna}$, $g_{Marte}$ y $g_{Júpiter}$
# * ¿Qué marcaría una báscula de baño si Fulanito se pesase en la Luna?

# %% [markdown]
# ## 3. Movimiento de los planetas: Sistema Sol y Tierra
#
# Nuestro planeta es una gran masa de tierra de forma [aproximadamente esférica](https://es.wikipedia.org/wiki/Geoide), situada en el Espacio y que gira alrededor de una [estrella](https://es.wikipedia.org/wiki/Estrella): El Sol. Dicha estrella tiene una masa muy superior a la de la Tierra y, debido a las leyes de la gravitación y a las [leyes de Kepler](https://es.wikipedia.org/wiki/Leyes_de_Kepler), podemos aproximar el movimiento de la Tierra alrededor del Sol como si fuese un **Moviento Circular Uniforme**, con:
#
# * Período
# * Frecuencia
# * Fuerzas centrípeta y centrífugas
# * Velocidad tangencial
#
# Bien, lo único que necesitamos saber para calcular lo anterior es lo siguiente:
#
# * La Tierra tiene una masa de $5,97\cdot 10^{24}\, kg$
# * El Sol tiene una masa de $1,9\cdot 10^{30}\, kg$
# * La distancia media Tierra-Sol es de $150000$ millones de $km$
# * La Tierra gira alrededor del Sol con **MCU**

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

####################################################################
### Para experimentar con la gravedad y ver cómo cambian         ###
### las órbitas, cambia los valores que aparecen a continuación: ###
####################################################################

# Masa del Sol en kg:
msol = 1.9*10**30
# Masa del planeta en kg:
mplaneta = 5.9*10**24
# Constante de gravitación universal:
G = 6.67*10**(-11)
# Distancia entre los dos planetas en m:
distancia = 149597870700


#######################################################################
## Empieza el cálculo: Puedes ver como se hace, pero si cambias algo ##
## es posible que el programa deje de funcionar!                     ##
#######################################################################
# Fuerza de atracción planeta-Sol:
Fgravedad = G*msol*mplaneta/(distancia**2)
# Aceleración centrípeta:
a = Fgravedad/distancia
# velocidad del planeta:
v = np.sqrt(Fgravedad*distancia/mplaneta)
# Período:
T     = 2*np.pi*distancia/v
Tdias = T/3600/24

print('Fuerza Sol-Planeta: {} Newtons'.format(Fgravedad))
print('Aceleración centrípeta: {} m/s^2'.format(a))
print('Velocidad: {} m/s'.format(v))
print('Período (en segundos): {} s'.format(T))
print('Período (en días): {} dias'.format(Tdias))

#######################################################################
## A partir de aquí, todo es código para hacer la animación...       ##
#######################################################################

centro_orbita = (7,7)

fig = plt.figure()
fig.set_dpi(100)
fig.set_size_inches(7, 6.5)
ax = plt.axes(xlim=(0, 14), ylim=(0, 14))

patchTierra = plt.Circle(centro_orbita, 0.25, fc='b')
patchLuna = plt.Circle((centro_orbita, 1), 0.1, fc='r')
patchSol = plt.Circle(centro_orbita, 0.75, fc='y')

def init():
    
    ax.set_aspect('equal')    
    ax.axis('off')
    ax.add_patch(patchTierra)
    ax.add_patch(patchSol)
    return patchTierra,patchSol,

factor_de_velocidad = 4
factor_v = 10
factor_aceleracion  = 15
dref = 149597870700
factor_de_distancia = 5*(distancia/dref)

vector_a = ax.quiver(0,0,0,0,angles='xy', scale_units='xy', scale=4.5,color='r')
vector_v = ax.quiver(0,0,0,0,angles='xy', scale_units='xy', scale=4.5)

def animate(i,vector_a,vector_v):
    
    # Hago que la figura de vueltas siguiendo la ecuación de un círculo.
    vref = 29100
    aref = 223334188210.7675
    x, y = patchTierra.center
    radianes = np.radians((v/vref)*i)
    
    x = centro_orbita[0] + factor_de_distancia*np.sin(radianes)
    y = centro_orbita[1] + factor_de_distancia*np.cos(radianes)
    
    vector_a.set_offsets(np.array([x,y]))
    vector_a.set_UVC(-factor_aceleracion*(a/aref)*np.sin(radianes),
                     -factor_aceleracion*(a/aref)*np.cos(radianes))
    
    vector_v.set_offsets(np.array([x,y]))
    vector_v.set_UVC(-factor_v*(v/vref)*np.sin((radianes-np.pi/2)),
                     -factor_v*(v/vref)*np.cos((radianes-np.pi/2)))
                       
    patchTierra.center = (x, y)
    return patchTierra,patchSol,vector_a,vector_v,

anim = animation.FuncAnimation(fig, animate, fargs=(vector_a,vector_v), 
                               init_func=init, 
                               frames=360, 
                               interval=17,
                               blit=True)
                                                     
                              
from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# Fuerza Sol-Planeta: 3.341031901084386e+22 Newtons
# Aceleración centrípeta: 223334188210.7675 m/s^2
# Velocidad: 29105.630486300754 m/s
# Período (en segundos): 32294477.991466343 s
# Período (en días): 373.7786804567864 dias
# <video width="700" height="650" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Ejercicio 4
#
# Deduce la **fórmula para hallar la velocidad de un planeta que orbita el Sol**:
#
# $$ v_{planeta} = \sqrt{\frac{G\cdot M_{Sol}}{d}}$$
#
# partiendo de la fórmula para la fuerza gravitatoria y de los conocimientos que tienes sobre el *Movimiento Circular Uniforme*. Fíjate en que la masa del planeta ($m_{planeta}$) no aparece en la fórmula.
#
# Cuando hallas terminado de deducir la fórmula, mira la gráfica de abajo. Como podrás observar, funciona bastante bien para nuestro [Sistema Solar](https://es.wikipedia.org/wiki/Sistema_Solar). Fíjate en que **cuánto más cerca está el planeta del Sol, más rápido se mueve**.

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 150

fig2,ax2=plt.subplots()
# Distancia media de los planetas al Sol, en millones de kilómetros
planetas_dist=[57.89,108.209,149.6,227.94,778.412,1426.72,2871,4498]
# Velocidad media de los planetas con respecto al Sol en m/s
planetas_v=[47872.5,35021,29780,24007,13070,9672.4,6810,5477.8]
planetas_nombre=['Mercurio','Venus','Tierra','Marte','Júpiter','Saturno','Neptuno','Urano']



distancia_vec = np.arange(50,5000,0.1)
v_vec = np.sqrt(G*msol/(distancia_vec*10**9))

plt.plot(distancia_vec,v_vec)
plt.plot(planetas_dist,planetas_v,'bo',ms=10)
plt.xlabel(r"Distancia media al Sol en millones de $km$")
plt.ylabel(r"Velocidad del planeta en $m/s$")

for i, txt in enumerate(planetas_nombre):
    ax2.annotate(txt,xy=(planetas_dist[i],planetas_v[i]),xytext=(planetas_dist[i]+100,planetas_v[i]+100))
    
plt.show()
